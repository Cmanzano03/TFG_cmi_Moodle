# %% [markdown]
# # Extracción de características de interacción con recursos y actividades

# %% [markdown]
# ## Importar las librerías necesarias y configurar el entorno

# %%
#  Spark y entorno
from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    col,
    count,
    sum,
    avg,
    min,
    max,
    when,
    lit,
    collect_list,
    size,
    to_date,
    dayofweek,
    datediff,
)
from pyspark.sql.types import IntegerType, StringType, TimestampType
import os

#  Crear SparkSession optimizada para entorno local
spark = (
    SparkSession.builder.appName("Moodle Feature Engineering")
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", "8")
    .config("spark.driver.memory", "8g")
    .config("spark.executor.memory", "8g")
    .config("spark.sql.execution.arrow.pyspark.enabled", "true")
    .getOrCreate()
)

# Confirmar recursos activos
print(f"✅ SparkSession iniciada con app: {spark.sparkContext.appName}")
print(f"🧠 Driver memory: {spark.sparkContext._conf.get('spark.driver.memory')}")
print(f"🧵 Núcleos disponibles: {spark.sparkContext.defaultParallelism}")
# Out:
# ✅ SparkSession iniciada con app: Moodle Feature Engineering
# 🧠 Driver memory: 8g
# 🧵 Núcleos disponibles: 8

# %% [markdown]
# ## Carga de datos

# %%
raw_data_path = "/home/carlos/Documentos/TFG/spark-workspace/data/raw"  # Ruta al directorio de datos crudos
file_names = os.listdir(raw_data_path)  # Listar los archivos en el directorio
print(file_names)

# # Leer el dataframe desde un archivo Parquet    
# df = spark.read.parquet(
#     os.path.join(raw_data_path, "moodle_data.parquet")
# )

# # Mostrar las primeras filas del dataframe
# df.show(5)
# Out:
# ['modules_cmi.parquet', 'course_modules_cmi.parquet', 'forum_cmi.parquet', 'quiz_attempts_cmi.parquet', 'assign_submission_cmi.parquet', 'alumnos_ip_cmi.parquet', 'quiz_cmi.parquet', 'assign_cmi.parquet', 'log_ip_cmi.parquet', 'assign_grades_cmi.parquet', 'forum_discussions_cmi.parquet', 'forum_posts_cmi.parquet']
# 25/05/26 14:55:00 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 2150730 ms exceeds timeout 120000 ms
# 25/05/26 14:55:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/05/26 14:55:03 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# ...

# %% [markdown]
# ##  Cálculo de métricas

# %% [markdown]
# ## Unión de datos y persitencia

# %% [markdown]
# ## Visualización y verificación
